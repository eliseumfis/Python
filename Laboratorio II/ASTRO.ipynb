# %%
import numpy as np
import math as math

# %%
V=5.5e-7; DV=8.9e-8
B=4.4e-7; DB=9.8e-8
U=3.65e-7; DU=6.8e-8
c=3e8 ; h=6.62e-34 ; k=1.38e-23
CUB=-0.87 ; CBV=0.65

T=22000

# %%
BV=-2.5*math.log10((V/B)**(5) * ((np.exp(h*c/(V*k*T))-1)/(np.exp(h*c/(B*k*T))-1)) * (DB/DV) ) +CBV

# %%
UB=-2.5*math.log10((B/U)**(5) * ((np.exp(h*c/(B*k*T))-1)/(np.exp(h*c/(U*k*T))-1)) * (DU/DB) ) +CUB

# %%
print(UB)
# Out:
# -1.0755742275532065
