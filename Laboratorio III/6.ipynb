# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
m=10
J=4.186

# %% [markdown]
# **4.5 [A]**

# %%
masa_4_5A = [310,300,290,280,270,260]
t45=[0,132,241,351,462,571]

t1=[0,30,60,90,120,150,180,210,240,270,300,330,360,390,420,450,480] # [s]
V1=[46.8,47.1,47.2,47.4,47.6,47.7,47.7,48.1,47.1,48.0,47.6,47.6,47.4,47.2,46.9,46.7,47.4] # [V]
I1=[4.5,4.42,4.52,4.57,4.58,4.6,4.59,4.62,4.58,4.62,4.59,4.58,4.58,4.53,4.53,4.53,4.57] # [A]

# %% [markdown]
# **4.0 [A]**

# %%
masa_4A=[300,290,280,270]
t4=[0,143,285,423]

#4.0
t2=[0,30,60,90,120,150,180,210,240,270,300,330,360,390,420]
V2=[42.1,42.7,42.9,42.7,42.7,42.3,42.5,42.1,41.8,41.8,42.8,41.8,43.3,42.2,43.0]
I2=[4.03,4.08,4.1,4.09,4.05,4.06,4.03,4.00,4.00,4.09,4.01,4.18,4.06,4.12]

# %% [markdown]
# **3.5 [A]**

# %%
masa_3_5A=[310,300,290,280]
t35=[0,217,406,602]

#3.5
t3=[0,30,60,90,120,150,180,210,240,270,300,330,360,390,420,450,480,510,540,570,600]
V3=[36.2,37.1,37.1,37.3,37.5,37.3,37.2,37.2,37.3,36.6,36.5,36.9,37.3,37.5,37.4,36.4,36.2,36.2,36.1,36.1,36.0]
I3=[3.48,3.56,3.56,3.59,3.60,3.58,3.57,3.56,3.57,3.51,3.50,3.53,3.57,3.60,3.59,3.49,3.46,3.47,3.46,3.45,3.45]

# %%
def L(i1,v1,i2,v2,delt1,delt2):
  return ((v2*i2-v1*i1)/(J*10) )* ((1/(delt2))-(1/(delt1)))**(-1)

# %%
print(len(t3))
# Out:
# 21

# %%
promI1=np.sum(I1)/len(I1)
promV1=np.sum(V1)/len(V1)

promI2=np.sum(I2)/len(I2)
promV2=np.sum(V2)/len(V2)

promI3=np.sum(I3)/len(I3)
promV3=np.sum(V3)/(len(V3))

# %%
print(promV3)
# Out:
# 36.828571428571436

# %%
#Data 1 y 2
print(L(promI1,promV1,promI2,promV2,109,138))
# Out:
# 539.2622361224088

# %%
### Data 1 y 3
print(L(promI3,promV3,promI1,promV1,189,110))
# Out:
# 540.6360963464117

# %%
# Data 2 y 3
print(L(promI3,promV3,promI2,promV2,196,143))
# Out:
# 536.6053439587481
