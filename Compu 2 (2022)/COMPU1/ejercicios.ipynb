# %% [markdown]
# # Desafíos de la clase 9

# %% [markdown]
# ## Ejercicio 1

# %%
from numpy import *
import matplotlib.pyplot as pl
from matplotlib import pyplot as plt

# y = 2t+5 ; x = 10t ; y(x)
# t = x/10

# %%
#y = x/5 + 5

y1 = 2*t+5
x1 = 10*t
t = arange(0,50)

#print(y1)
#print(x1)

pl.plot(x1,y1)
pl.show()

# %% [markdown]
# ## Ejercicio 2

# %%
# x(t) = 5 + 3t
t0 = arange(0,20)
print(len(t0))
x = 5 + 3*t0
print(x)
pl.plot(x,t0)
pl.show()
# Out:
# 20
# [ 5  8 11 14 17 20 23 26 29 32 35 38 41 44 47 50 53 56 59 62]

# %% [markdown]
# ## Ejercicio 3

# %%
#x(t) = 40*t - 1/2 a*t**2
#v(t) = 40 - a*t
#a(t) = 5 [m/s^2]

# %%
x2 = []
#v2 = []
#t2 = []
#tl = arange(0,0.0000000001)
#a = 5 * tl

for t in range(0,9):
    x2.append(40*t-1/2*a*t**2)
    #v2.append(40-a*t)
    #t2.append(t)
print(x2) #print(v2)

print(type(x2))
pl.plot(x2)
#pl.plot(v2)
#pl.plot(a)
# Out:
# [array([0.]), array([40.]), array([80.]), array([120.]), array([160.]), array([200.]), array([240.]), array([280.]), array([320.])]
# <class 'list'>

# %% [markdown]
# ## Ejercicio 4

# %%
# 1 
#x(t) = 50 * t - 0.5 * 2 * t**2
#
#v(t) = 50 - 2t
#t = 25[s]
# 2
#v'(t) = 0 - 2t

xf = 50 * 25 - 0.5 * 2 * 25**2;print(xf)
t14 = (50 + sqrt(50**2-4*200))/2 
t24 = (50 - sqrt(50**2-4*200))/2; print(t14,t24) #t24 es la respuesta correcta del ejercicio
# Out:
# 625.0
# 45.6155281280883 4.384471871911696
